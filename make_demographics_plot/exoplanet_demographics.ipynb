# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('xtick', labelsize=27) 
matplotlib.rc('ytick', labelsize=27)

# use latex for font rendering
matplotlib.rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
matplotlib.rc('text', usetex=True)

# %%
data = pd.read_csv('exoplanet_data_sunlike_11.27.2022.csv')
data_all = pd.read_csv('exoplanet_data_11.27.2022.csv')

# %%
print(data_all.columns)
# Out:
# Index(['pl_name', 'hostname', 'sy_snum', 'sy_pnum', 'pl_controv_flag',
#        'pl_orbper', 'pl_orbpererr1', 'pl_orbpererr2', 'pl_orbperlim',
#        'pl_rade', 'pl_radeerr1', 'pl_radeerr2', 'pl_radelim', 'pl_bmasse',
#        'pl_bmasseerr1', 'pl_bmasseerr2', 'pl_bmasselim', 'st_rad',
#        'st_raderr1', 'st_raderr2', 'st_radlim', 'st_mass', 'st_masserr1',
#        'st_masserr2', 'st_masslim'],
#       dtype='object')

# %%
periods = data['pl_orbper']
masses = data['pl_bmasse']


periods_all = data_all['pl_orbper']
masses_all = data_all['pl_bmasse']

# %%
#from here: https://nssdc.gsfc.nasa.gov/planetary/factsheet/earthfact.html
m_earth = 1. # [m_earth]
p_earth = 365.256 # [days] sidereal

# %%
#from here: https://nssdc.gsfc.nasa.gov/planetary/factsheet/jupiterfact.html
m_jup = 317.83 # [m_earth]
p_jup = 4332.589 # [days] sidereal

# %%
#from here: https://nssdc.gsfc.nasa.gov/planetary/factsheet/saturnfact.html
m_saturn = 95.16 # [m_earth]
p_saturn = 10759.22 #[ days] sidereal

# %%
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

def getImage(path):
    return OffsetImage(plt.imread(path))

# %%
fig, ax = plt.subplots(1, 1, figsize = [15,15])
ax.plot(periods, masses, 'o', color = "#7b3e65", alpha = 0.3, markersize = 13)


ax.text(.03, .97, str(len(periods)) + ' confirmed exoplanets around Sun-like stars',
       ha='left', va='top', transform=ax.transAxes, fontsize=27, fontweight='bold')

ax.set_yscale('log')
ax.set_xscale('log')




paths = [
    'earth.png',
    'jupiter.png',
    'saturn.png',
    ]

y = [m_earth,m_jup,m_saturn]
x = [p_earth,p_jup,p_saturn]

ax.scatter(x, y) 

for x0, y0, path in zip(x, y, paths):
    ab = AnnotationBbox(getImage(path), (x0, y0), 
                        frameon=False)
    ax.add_artist(ab)
    

ax.set_xlim(.1, 500000)
ax.set_ylim(.1, 50000)

ax.set_ylabel(r'Mass [M$_{Earth}$]', fontsize = 36)
ax.set_xlabel('Orbital Period [days]', fontsize = 36)

fig.savefig('exoplanets_sun-like.pdf')

fig.tight_layout()

# %%
fig, ax = plt.subplots(1, 1, figsize = [15,15])
ax.plot(periods_all, masses_all, 'o', color = "#7b3e65", alpha = 0.3, markersize = 13)

ax.text(.03, .97, str(len(periods_all)) + ' confirmed exoplanets in total',
       ha='left', va='top', transform=ax.transAxes, fontsize=27, fontweight='bold')

ax.set_yscale('log')
ax.set_xscale('log')




paths = [
    'earth.png',
    'jupiter.png',
    'saturn.png',
    ]

y = [m_earth,m_jup,m_saturn]
x = [p_earth,p_jup,p_saturn]

ax.scatter(x, y) 

for x0, y0, path in zip(x, y, paths):
    ab = AnnotationBbox(getImage(path), (x0, y0), 
                        frameon=False)
    ax.add_artist(ab)
    

ax.set_xlim(.1, 500000)
ax.set_ylim(.1, 50000)

ax.set_ylabel(r'Mass [M$_{Earth}$]', fontsize = 36)
ax.set_xlabel('Orbital Period [days]', fontsize = 36)

#ax.set_title('confirmed exoplanets', fontsize = 36)

fig.savefig('exoplanets_all.pdf')

# %%
fig, ax = plt.subplots(1, 1, figsize = [15,15])
ax.plot(periods_all, masses_all, 'o', color = "#7b3e65", alpha = 0.3, markersize = 13)

ax.text(.03, .97, str(len(periods_all)) + ' confirmed exoplanets in total',
       ha='left', va='top', transform=ax.transAxes, fontsize=36, fontweight='bold')

ax.set_yscale('log')
ax.set_xscale('log')




colors = ['#366537', 
          '#db372b', 
          '#b4943e']

planets = [
    'Earth',
    'Jupiter',
    'Saturn',
    ]

y = [m_earth,m_jup,m_saturn]
x = [p_earth,p_jup,p_saturn]

ax.scatter(x, y) 

for x0, y0, color, planet in zip(x, y, colors, planets):
    ax.plot(x0, y0, 'ks', color = color, markersize = 18, label=planet)
 

ax.set_xlim(.1, 500000)
ax.set_ylim(.1, 50000)

ax.set_ylabel(r'Mass [M$_{Earth}$]', fontsize = 36)
ax.set_xlabel('Orbital Period [days]', fontsize = 36)

ax.legend(fontsize=36, loc=4)

fig.savefig('exoplanets_all_paper.pdf')
# Out:
# /var/folders/9z/bcj7jltn3x5_8y20r9cxql3h0000gn/T/ipykernel_69341/692343191.py:29: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ks" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x0, y0, 'ks', color = color, markersize = 18, label=planet)

# %%
fig, ax = plt.subplots(1, 1, figsize = [15,15])
ax.plot(periods, masses, 'o', color = "#7b3e65", alpha = 0.3, markersize = 13)


ax.text(.03, .97, str(len(periods)) + ' confirmed exoplanets around Sun-like stars',
       ha='left', va='top', transform=ax.transAxes, fontsize=36, fontweight='bold')

ax.set_yscale('log')
ax.set_xscale('log')


colors = ['#366537', 
          '#db372b', 
          '#b4943e']

planets = [
    'Earth',
    'Jupiter',
    'Saturn',
    ]

y = [m_earth,m_jup,m_saturn]
x = [p_earth,p_jup,p_saturn]

ax.scatter(x, y) 

for x0, y0, color, planet in zip(x, y, colors, planets):
    ax.plot(x0, y0, 'ks', color = color, markersize = 18, label=planet)
    

ax.set_xlim(.1, 500000)
ax.set_ylim(.1, 50000)

ax.set_ylabel(r'Mass [M$_{Earth}$]', fontsize = 36)
ax.set_xlabel('Orbital Period [days]', fontsize = 36)

ax.legend(fontsize=36, loc=4)

fig.savefig('exoplanets_sun-like_paper.pdf')

fig.tight_layout()
# Out:
# /var/folders/9z/bcj7jltn3x5_8y20r9cxql3h0000gn/T/ipykernel_69341/2030696287.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ks" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x0, y0, 'ks', color = color, markersize = 18, label=planet)
